# %%
# !pip install beautifulsoup4
# !pip install requests

# %%
# !pip list
# Out:
# Package                            Version
# ---------------------------------- --------------------
# absl-py                            1.3.0
# alabaster                          0.7.12
# anaconda-client                    1.9.0
# anaconda-navigator                 2.1.1
# anaconda-project                   0.10.1
# anyio                              2.2.0
# appdirs                            1.4.4
# argh                               0.26.2
# argon2-cffi                        20.1.0
# arrow                              0.13.1
# asgiref                            3.5.2
# asn1crypto                         1.4.0
# astroid                            2.6.6
# astropy                            4.3.1
# astunparse                         1.6.3
# async-generator                    1.10
# atomicwrites                       1.4.0
# attrs                              21.2.0
# autopep8                           1.5.7
# Babel                              2.9.1
# ...

# %%
# !pip install lxml

# %%
vi parser.py
# Out:
#   File "C:\Users\admin\AppData\Local\Temp/ipykernel_3544/461311828.py", line 1
#     vi parser.py
#        ^
# SyntaxError: invalid syntax

# %%
import requests
from bs4 import BeautifulSoup

url = 'https://www.glowpick.com/products/132171'

res = requests.get(url)
res.raise_for_status()  # 문제 있으면 종료

soup = BeautifulSoup(res.text, "lxml")

items = soup.find_all(attrs={"class":"basicList_link_1MaTN"})
for i in range(len(items)):
    print(i+1, items[i].get_text())

if response.status_code == 200:
    html = response.text
    soup = BeautifulSoup(html, 'html.parser')
    title = soup.select_one('#product-132171 > div.product__details.details > p.details__product > span > b > span')
    print(title)

else : 
    print(response.status_code)
# Out:
# 200

# %%
import requests
from bs4 import BeautifulSoup

url = 'https://www.glowpick.com/products/132171'

res = requests.get(url)
res.raise_for_status()  # 문제 있으면 종료

soup = BeautifulSoup(res.text, "lxml")

items = soup.find_all(attrs={"class":"basicList_link_1MaTN"})
for i in range(len(items)):
    print(i+1, items[i].get_text())

# %%
# !pip install selenium
# Out:
# ...
#      ---------------------------------------- 6.3/6.3 MB 3.6 MB/s eta 0:00:00
# ...
#      -------------------------------------- 384.9/384.9 kB 2.7 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 58.3/58.3 kB ? eta 0:00:00
# ...

# %%
import requests
from bs4 import BeautifulSoup

# 글로우픽 서버에 대화 시도
URL = "https://www.glowpick.com/"
raw = requests.get(URL)
html = BeautifulSoup(raw.text, 'html.parser')
target = html.find_all('a',{'class':'title'})

options = driver.find_elements_by_tag_name('#contents > section > div.product__info.info > article.info__article.description > div > p')
#.description__list


for title in target:
    print('상품 정보:', title.text)
    
print(title)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_3544/2840067431.py in <module>
#       8 target = html.find_all('a',{'class':'title'})
#       9
# ---> 10 options = driver.find_elements_by_tag_name('#contents > section > div.product__info.info > article.info__article.description > div > p')
#      11 #.description__list
#      12
#
# NameError: name 'driver' is not defined

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By

url = "https://www.glowpick.com/categories/2?ids=6"
browser = webdriver.Chrome()
browser.get(url)

element = browser.find_element(By.CLASS_NAME, 'description__list__item info__text info__text-gray')

#element.click()
print(browser.page_source)
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_3544/173376491.py in <module>
#       6 browser.get(url)
#       7
# ----> 8 element = browser.find_element(By.CLASS_NAME, 'description__list__item info__text info__text-gray')
#       9
#      10 #element.click()
#
# C:\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element(self, by, value)
#     859             value = '[name="%s"]' % value
#     860
# --> 861         return self.execute(Command.FIND_ELEMENT, {"using": by, "value": value})["value"]
#     862
#     863     def find_elements(self, by=By.ID, value: Optional[str] = None) -> List[WebElement]:
#
# C:\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     442         response = self.command_executor.execute(driver_command, params)
# ...

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By

url = "http://naver.com"
browser = webdriver.Chrome()
browser.get(url)

element = browser.find_element(By.CLASS_NAME, 'link_login')

element.click()

# %%
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
import csv

# %%
# csv파일 생성
f = open('cosmetic.csv', 'w', encoding="utf-8-sig", newline='')
w = csv.writer(f)
w.writerow(['이름', '용량', '가격', '성분', '사용기한'])
# Out:
# 18

# %%
# 아래의 함수를 사용하여 크롬 창을 열지 않고 백그라운드로 실행
option = webdriver.ChromeOptions()
option.add_argument('headless')

# %%
# 옵션에 위에서 만든 option을 추가
url = 'http://naver.com'
browser = webdriver.Chrome(options=option)
browser.get(url)

browser.find_element(By.ID, 'query').send_keys("보습", Keys.ENTER)
url = browser.find_element(By.CLASS_NAME, 'api_more_theme').get_attribute('href')
browser.get(url)
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_3544/2595043010.py in <module>
#       5
#       6 browser.find_element(By.ID, 'query').send_keys("보습", Keys.ENTER)
# ----> 7 url = browser.find_element(By.CLASS_NAME, 'api_more_theme').get_attribute('href')
#       8 browser.get(url)
#
# C:\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element(self, by, value)
#     859             value = '[name="%s"]' % value
#     860
# --> 861         return self.execute(Command.FIND_ELEMENT, {"using": by, "value": value})["value"]
#     862
#     863     def find_elements(self, by=By.ID, value: Optional[str] = None) -> List[WebElement]:
#
# C:\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     442         response = self.command_executor.execute(driver_command, params)
# ...
